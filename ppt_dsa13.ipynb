# %% [markdown]
# #### **Question 1**
# #### Given two linked list of the same size, the task is to create a new linked list using those linked lists. The condition is that the greater node among both linked list will be added to the new linked list.
# #### **Examples:**
# #### Input: list1 = 5->2->3->8
# #### list2 = 1->7->4->5
# #### Output: New list = 5->7->4->8
#
# #### Input:list1 = 2->8->9->3
# #### list2 = 5->3->6->4
# #### Output: New list = 5->8->9->4

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
    def print_ll(self):
        if self.head==None:
            print("linked list is empty")
        else:
            n=self.head
            while n is not None:
                print(n.data)
                n=n.next
    def add_at_began(self,data):
        new_node=node(data)
        new_node.next=self.head
        self.head=new_node
        return self.head
    def add_at_end(self,data):
        new_node=node(data)
        n=self.head
        while n.next is not None:
            n=n.next
        n.next=new_node
        
        return self.head
   
   
        
def takelist(head1,head2):
#     curr1 = head1
#     print("first list")
#     while curr1:
#         print(curr1.data)
#         curr1=curr1.next
        
#     curr2 = head2
#     print("second list")
#     while curr2:
#         print(curr2.data)
#         curr2=curr2.next
        
        
    curr3 = head1
    curr4 = head2
    while curr3:
        if curr3.data<curr4.data:
            curr3.data=curr4.data
        curr3=curr3.next
        curr4=curr4.next
        
    
    
        
    
    
    
    
    
c1=linkedlist()
c1.add_at_began(5)
c1.add_at_end(2)
c1.add_at_end(3)
k1=c1.add_at_end(8)
print("printing list1")
c1.print_ll()
c2 = linkedlist()
c2.add_at_began(1)
c2.add_at_end(7)
c2.add_at_end(4)
k2=c2.add_at_end(5)
print("printing list 2")
c2.print_ll()
print("New era")
takelist(k1,k2)
print("After making changes")
c1.print_ll()
# Out:
# printing list1
# 5
# 2
# 3
# 8
# printing list 2
# 1
# 7
# 4
# 5
# New era
# After making changes
# 5
# 7
# 4
# 8

# %% [markdown]
# #### **Question 2**
# #### Write a function that takes a list sorted in non-decreasing order and deletes any duplicate nodes from the list. The list should only be traversed once. For example if the linked list is 11->11->11->21->43->43->60 then removeDuplicates() should convert the list to 11->21->43->60.
# #### **Example 1:**
# #### Input:
# #### LinkedList:
# #### 11->11->11->21->43->43->60
# #### Output:
# #### 11->21->43->60

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
    def print_ll(self):
        if self.head==None:
            print("linked list is empty")
        else:
            n=self.head
            while n is not None:
                print(n.data)
                n=n.next
    def add_at_began(self,data):
        new_node=node(data)
        new_node.next=self.head
        self.head=new_node
    def add_at_end(self,data):
        new_node=node(data)
        n=self.head
        while n.next is not None:
            n=n.next
        n.next=new_node
        

    def remove_duplicates(self):
        if self.head is None:
            return self.head
        
        curr = self.head
        while curr.next is not None:
            if curr.data==curr.next.data:
                curr.next=curr.next.next
            else:
                curr=curr.next

        
        
        
c1=linkedlist()
c1.add_at_began(11)
c1.add_at_end(11)
c1.add_at_end(11)
c1.add_at_end(21)
c1.add_at_end(43)
c1.add_at_end(43)
c1.add_at_end(60)
print("printing list1")
c1.print_ll()  
print("removing duplicates")
c1.remove_duplicates()
c1.print_ll()
# Out:
# printing list1
# 11
# 11
# 11
# 21
# 43
# 43
# 60
# removing duplicates
# 11
# 21
# 43
# 60

# %% [markdown]
# #### **Question 5**
# #### Given a linked list and a key to be deleted. Delete last occurrence of key from linked. The list may have duplicates.
# #### **Examples**:
# #### Input:   1->2->3->5->2->10, key = 2
# #### Output:  1->2->3->5->10

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
    def print_ll(self):
        if self.head==None:
            print("linked list is empty")
        else:
            n=self.head
            while n is not None:
                print(n.data)
                n=n.next
    def add_at_began(self,data):
        new_node=node(data)
        new_node.next=self.head
        self.head=new_node
    def add_at_end(self,data):
        new_node=node(data)
        n=self.head
        while n.next is not None:
            n=n.next
        n.next=new_node
        
    def del_at_last_occurance(self,key):
        if self.head is None:
            return None
        
        p=self.head
        temp = None
        
        while p:
            if(p.data==key):
                temp = p
            p=p.next
            
        if(temp==None):
            return self.head
        
        elif(temp==self.head):
            self.head=self.head.next
            return self.head
        
        elif(temp.next==None):
            node=self.head
            while(node.next.next!=None):
                node=node.next
            node.next=None
            return self.head
        
        else:
            temp.data=temp.next.data
            temp.next=temp.next.next
            
    
            
            
            
        
        
        
c1=linkedlist()
c1.add_at_began(1)
c1.add_at_end(2)
c1.add_at_end(3)
c1.add_at_end(5)
c1.add_at_end(2)
c1.add_at_end(10)
print("printing list1")
c1.print_ll()  
print("after deleting")
print(c1.del_at_last_occurance(2))

c1.print_ll()
# Out:
# printing list1
# 1
# 2
# 3
# 5
# 2
# 10
# after deleting
# None
# 1
# 2
# 3
# 5
# 10

# %% [markdown]
# #### **Question 6**
# #### Given two sorted linked lists consisting of **N** and **M** nodes respectively. The task is to merge both of the lists (in place) and return the head of the merged list.
# #### **Examples:**
# #### Input: a: 5->10->15, b: 2->3->20
# #### Output: 2->3->5->10->15->20
# #### Input: a: 1->1, b: 2->4
# #### Output: 1->1->2->4

# %%
class Node:
    def __init__(self, key):
        self.key = key
        self.next = None
         
def newNode(key):
    return Node(key)
 

a = Node(5)
a.next = Node(10)
a.next.next = Node(15)
a.next.next.next = Node(40)
 
b = Node(2)
b.next = Node(3)
b.next.next = Node(20)
 
v = []
while(a is not None):
    v.append(a.key)
    a = a.next
    
    
    
while(b is not None):
    v.append(b.key)
    b = b.next

    
v.sort()
result = Node(-1)
temp = result
for i in range(len(v)):
    result.next = Node(v[i])
    result = result.next

    
    
temp = temp.next
print("Resultant Merge Linked List is : ")
while(temp is not None):
    print(temp.key, end=" ")
    temp = temp.next
# Out:
# Resultant Merge Linked List is :
# 2 3 5 10 15 20 40

# %% [markdown]
# #### **Question 7**
# #### Given a **Doubly Linked List**, the task is to reverse the given Doubly Linked List.
# #### **Example:**
# #### Original Linked list 10 8 4 2
# #### Reversed Linked list 2 4 8 10

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class doubly_linked_list:
    def __init__(self):
        self.head = None


    def push(self, NewVal):
        NewNode = Node(NewVal)
        NewNode.next = self.head
        if self.head is not None:
            self.head.prev = NewNode
        self.head = NewNode


    def append(self, NewVal):
        NewNode = Node(NewVal)
        NewNode.next = None
        if self.head is None:
            NewNode.prev = None
            self.head = NewNode
            return
        last = self.head
        while (last.next is not None):
            last = last.next
        last.next = NewNode
        NewNode.prev = last
        return


    def listprint(self, node):
        while (node is not None):
            print(node.data)
            last = node
            node = node.next
            
    def reverse(self,node):
        current = node
        previous = None
        while current:
            previous = current
            current=current.next

        while previous:
            print(previous.data)
            previous=previous.prev

        
    
    
dllist = doubly_linked_list()
dllist.push(12)
dllist.append(9)
dllist.append(8)
dllist.append(62)
dllist.append(45)
dllist.listprint(dllist.head)
print("After Reversing")
dllist.reverse(dllist.head)
# Out:
# 12
# 9
# 8
# 62
# 45
# After Reversing
# 45
# 62
# 8
# 9
# 12

# %% [markdown]
# #### **Question 8**
# #### Given a doubly linked list and a position. The task is to delete a node from given position in a doubly linked list.
# #### **Example 1:**
# ##### Input:
# #### LinkedList = 1 <--> 3 <--> 4
# #### x = 3
# #### Output:1 3
# #### Explanation:After deleting the node at
# #### position 3 (position starts from 1), the linked list will be now as 1->3.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class doubly_linked_list:
    def __init__(self):
        self.head = None


    def push(self, NewVal):
        NewNode = Node(NewVal)
        NewNode.next = self.head
        if self.head is not None:
            self.head.prev = NewNode
        self.head = NewNode


    def append(self, NewVal):
        NewNode = Node(NewVal)
        NewNode.next = None
        if self.head is None:
            NewNode.prev = None
            self.head = NewNode
            return
        last = self.head
        while (last.next is not None):
            last = last.next
        last.next = NewNode
        NewNode.prev = last
        return


    def listprint(self, node):
        while (node is not None):
            print(node.data)
            last = node
            node = node.next
            
            
    def delete(self,node,key):
        curr = node
        count = 0
        
        while curr:
            count+=1
            curr=curr.next
            
        if key>count:
            return node
        
        pos = 0
        
        curr1 = node
        previous = None
        
        while pos!=key:
            previous = curr1
            curr1=curr1.next
            pos+=1
            
        if previous==node:
            return node.next
        
        if previous.next==None:
            previous.prev.next=None
            return node
        
        previous.prev.next=previous.next
        previous.next=None
        previous.prev=None
        
        return node
        
        
            
dllist = doubly_linked_list()
dllist.push(1)
dllist.append(3)
dllist.append(4)
print("printing before deleting")
dllist.listprint(dllist.head)
k=dllist.delete(dllist.head,3)
print("printing After deleting")
dllist.listprint(k)
# Out:
# printing before deleting
# 1
# 3
# 4
# printing After deleting
# 1
# 3
